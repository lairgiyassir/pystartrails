# %% [markdown]
# # Importing the modules

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import matplotlib.pyplot as plt

sys.path.append("..")
from src import TrailsGenerator

# %% [markdown]
# # Star Trails

# %%
trails_gen = TrailsGenerator(sequence_repository="C:/Users/LENOVO/Desktop/raw",generated_img_extension="jpg", generated_img_name="milkyway")

# %%
generated_img = trails_gen.generate_trails()
# Out:
# 100%|██████████| 10/10 [00:04<00:00,  2.17it/s]

# %% [markdown]
# If you do not specify the repository of the generated img, it will be stored by default in the sequence repository.

# %% [markdown]
# # Show the img
# ---

# %%
plt.imshow(generated_img)
plt.show()
